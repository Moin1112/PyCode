# %% [markdown]
# <a href="https://colab.research.google.com/github/Moin1112/PyCode/blob/main/Image_Processing_with_CNN_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import os
import random
import matplotlib.pyplot as plt

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DIRECTORY= r"/content/drive/MyDrive/leaf"
CATAGORIES= ['Strawberry_fresh','Strawberry_scrotch']

# %%
data=[]

for categories in CATAGORIES:
    folder=os.path.join(DIRECTORY,categories)
    label=CATAGORIES.index(categories)
    
    
    for img in os.listdir(folder):
        img=os.path.join(folder,img)
        img_arr=cv2.imread(img)
        img_arr=cv2.resize(img_arr,(100,100))
        
        data.append([img_arr,label])

# %%
data
# Out:
# [[array([[[156, 146, 158],
#           [142, 132, 144],
#           [134, 124, 136],
#           ...,
#           [160, 150, 162],
#           [162, 152, 164],
#           [164, 154, 166]],
#
#          [[133, 123, 135],
#           [171, 161, 173],
#           [152, 142, 154],
#           ...,
#           [158, 148, 160],
#           [161, 151, 163],
#           [162, 152, 164]],
#
#          [[134, 124, 136],
#           [157, 147, 159],
#           [127, 117, 129],
#           ...,
#           [163, 153, 164],
#           [163, 153, 165],
#           [160, 150, 162]],
#
#          ...,
#
#          [[151, 144, 151],
#           [172, 165, 172],
#           [199, 192, 199],
#           ...,
#           [182, 169, 177],
#           [176, 163, 171],
#           [180, 167, 175]],
#
#          [[174, 167, 174],
#           [191, 184, 191],
#           [195, 188, 195],
#           ...,
#           [172, 159, 167],
#           [178, 165, 173],
#           [175, 162, 170]],
#
# ...

# %%
random.shuffle(data)

# %%
x=[]
y=[]


for features,label in data:
    x.append(features)
    y.append(label)

# %%
X= np.array(x)
Y=np.array(y)

# %%
x
# Out:
# [array([[[136, 129, 136],
#          [149, 142, 149],
#          [149, 142, 149],
#          ...,
#          [170, 162, 169],
#          [157, 149, 156],
#          [167, 159, 166]],
#
#         [[148, 140, 148],
#          [164, 157, 164],
#          [153, 147, 153],
#          ...,
#          [167, 159, 166],
#          [164, 156, 163],
#          [162, 154, 161]],
#
#         [[145, 138, 145],
#          [147, 139, 147],
#          [174, 167, 174],
#          ...,
#          [161, 153, 160],
#          [161, 153, 160],
#          [169, 161, 168]],
#
#         ...,
#
#         [[179, 172, 177],
#          [194, 187, 192],
#          [192, 185, 190],
#          ...,
#          [189, 176, 184],
#          [186, 173, 181],
#          [181, 168, 176]],
#
#         [[185, 178, 183],
#          [164, 157, 162],
#          [182, 175, 180],
#          ...,
#          [180, 167, 175],
#          [182, 169, 177],
#          [180, 167, 175]],
#
#         [[192, 185, 190],
# ...

# %%
X=X/255

# %%
X
# Out:
# array([[[[0.53333333, 0.50588235, 0.53333333],
#          [0.58431373, 0.55686275, 0.58431373],
#          [0.58431373, 0.55686275, 0.58431373],
#          ...,
#          [0.66666667, 0.63529412, 0.6627451 ],
#          [0.61568627, 0.58431373, 0.61176471],
#          [0.65490196, 0.62352941, 0.65098039]],
#
#         [[0.58039216, 0.54901961, 0.58039216],
#          [0.64313725, 0.61568627, 0.64313725],
#          [0.6       , 0.57647059, 0.6       ],
#          ...,
#          [0.65490196, 0.62352941, 0.65098039],
#          [0.64313725, 0.61176471, 0.63921569],
#          [0.63529412, 0.60392157, 0.63137255]],
#
#         [[0.56862745, 0.54117647, 0.56862745],
#          [0.57647059, 0.54509804, 0.57647059],
#          [0.68235294, 0.65490196, 0.68235294],
#          ...,
#          [0.63137255, 0.6       , 0.62745098],
#          [0.63137255, 0.6       , 0.62745098],
#          [0.6627451 , 0.63137255, 0.65882353]],
#
#         ...,
#
# ...

# %%
X.shape
# Out:
# (100, 100, 100, 3)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Activation

# %%
model=Sequential()
model.add( Conv2D(64,(3,3),input_shape=X.shape[1:],activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add( Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add( Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Flatten())

model.add(Dense(2,activation='softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X,Y,epochs=15,validation_split=0.1)
# Out:
# Epoch 1/15
# 3/3 [==============================] - 3s 727ms/step - loss: 0.6852 - accuracy: 0.5000 - val_loss: 0.6669 - val_accuracy: 0.7000
# Epoch 2/15
# 3/3 [==============================] - 2s 626ms/step - loss: 0.6774 - accuracy: 0.5222 - val_loss: 0.6332 - val_accuracy: 0.8000
# Epoch 3/15
# 3/3 [==============================] - 2s 605ms/step - loss: 0.6460 - accuracy: 0.5444 - val_loss: 0.6160 - val_accuracy: 0.8000
# Epoch 4/15
# 3/3 [==============================] - 2s 624ms/step - loss: 0.5947 - accuracy: 0.7778 - val_loss: 0.5410 - val_accuracy: 0.8000
# Epoch 5/15
# 3/3 [==============================] - 3s 1s/step - loss: 0.5288 - accuracy: 0.8333 - val_loss: 0.4639 - val_accuracy: 0.8000
# Epoch 6/15
# 3/3 [==============================] - 3s 963ms/step - loss: 0.4211 - accuracy: 0.9333 - val_loss: 0.3407 - val_accuracy: 0.9000
# Epoch 7/15
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 98, 98, 64)        1792
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 2)                 6402
#
# ...
# Total params: 35,906
# Trainable params: 35,906
# Non-trainable params: 0
# _________________________________________________________________
