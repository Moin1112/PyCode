# %% [markdown]
# <a href="https://colab.research.google.com/github/Moin1112/PyCode/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpts = np.array([0,4])
ypts = np.array([0,50])
plt.plot(xpts,ypts)
plt.show()
